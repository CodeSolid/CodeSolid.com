# %% [markdown]
# # Linear Algebra with SymPy
#
# Topics:
#
# ## Systems of Equations
# ## Reduced Row Echelon Form (rref)
# ## Matrix Multiplication
# ## Determinants
# ## Rank
# ## Cofactors & Laplace Expansion aka Expansion by Cofactors:
# https://www.youtube.com/watch?v=aICtl-9J6rs
