# %% [markdown]
# # My First Linear Algebra Sage Notebook
#
# What to do, what to do.  Let's multiply, of course

# %%
A = random_matrix(QQ, 3, 2)
print(A)
print("\n-----------\n")
B = random_matrix(QQ, 2, 2)
print(B)
print("\n-----------\n")
print(A*B)
assert A.ncols() == B.nrows()
# The following is Unsupported as designed.
# print(B*A)
# TypeError: unsupported operand parent(s) for *: 'Full MatrixSpace of 2 by 2 dense matrices 
# over Rational Field' and 'Full MatrixSpace of 3 by 2 dense matrices over Rational Field'
# Out:
# [ 2 -1]
# [ 0 -1]
# [ 1 -2]
#
# -----------
#
# [  0  -1]
# [  0 1/2]
#
# -----------
#
# [   0 -5/2]
# [   0 -1/2]
# [   0   -2]
