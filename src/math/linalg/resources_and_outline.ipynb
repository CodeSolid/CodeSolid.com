# %% [markdown]
# # Linear Algebra Resources and Outline
#
# ## Course 1.0 - Introduction and Overview
#
# * [Phoenix MOOC for Linear Algebra](https://moer.maricopa.edu/course/course.php?cid=17067&folder=0).  To register, see [this page](https://www.phoenixcollege.edu/degrees-certificates/mathematics/self-study-math-moocs)
# * OR [Wrath of Math Linear Algebra Playlist](https://www.youtube.com/playlist?list=PLztBpqftvzxWT5z53AxSqkSaWDhAeToDG) - In progress.
# * OR (AND?) Gilbert Strang Lectures on Linear Algebra.  [Youtube Playlist](https://www.youtube.com/playlist?list=PL49CF3715CB9EF31D).  Course web site is [https://web.mit.edu/18.06](https://web.mit.edu/18.06)
# * SymPy and SageMath Notebooks
#
# ## Course 2.0 Advanced topics
# * The main text might be [Linear Algebra Done Right](https://linear.axler.net/LADR4e.pdf).  There is companion [Youtube Playlist](https://www.youtube.com/playlist?list=PLGAnmvB9m7zOBVCZBUUmSinFV0wEir2Vw).  His web site is [axler.net](https://linear.axler.net/)
# * Mark Beck’s "Quantum Mechanics: Theory and Experiment"
# * Mark Newman's Computational Physics
